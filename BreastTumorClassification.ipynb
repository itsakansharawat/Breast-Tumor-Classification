# %% [markdown]
# # **BREAST TUMOR PREDICTION**

# %% [markdown]
# -> Gaussian Naïve Bayes classifier

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("/content/data.csv")

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# Simple way to do it -

# %%
X = data.drop("diagnosis",axis=1)

# %%
Y = data["diagnosis"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=45)

# %%
Y = data[data.columns[1]]

# %%
X_train.shape
# Out:
# (455, 32)

# %%
Y_train.shape
# Out:
# (455,)

# %%
Y_train.value_counts()
# Out:
# B    285
# M    170
# Name: diagnosis, dtype: int64

# %%
X_test.shape
# Out:
# (114, 32)

# %%
Y_test.shape
# Out:
# (114,)

# %%
Y_test.value_counts()
# Out:
# B    72
# M    42
# Name: diagnosis, dtype: int64

# %%
### Not as effective as StratifiedShuffling.

# %%
Y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
num_B_tumors = data[data[data.columns[1]]=='B'].shape[0]

# %%
num_M_tumors = data[data[data.columns[1]]=='M'].shape[0]

# %%
num_B_tumors
# Out:
# 357

# %%
num_M_tumors
# Out:
# 212

# %%
data_M= data[data[data.columns[0]]=='M']

# %%
data_M
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %%
data_B= data[data[data.columns[0]]=='B']
data_B
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ###It is an UNBALANCED DATASET because the nominal classification is not divided properly.

# %%
data.drop(labels =[data.columns[0],data.columns[-1]],axis=1,inplace=True)

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ###Balancing the data now!

# %%
train_per=int(0.7*data.shape[0])

# %%
train_per
# Out:
# 398

# %%
train_rows_M =int(train_per/2)

# %%
train_rows_M
# Out:
# 199

# %%
train_rows_B =int(train_per/2)

# %%
train_rows_B
# Out:
# 199

# %%
train_M = data_M.iloc[:train_rows_M,:]

# %%
train_M
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %%
train_B = data_B.iloc[:train_rows_B,:]

# %%
train_B
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %%
data1 =pd.concat([train_M,train_B])

# %%
data1['diagnosis'].value_counts()
# Out:
# Series([], Name: diagnosis, dtype: int64)

# %%
data1
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ### AN ALTERNATIVE WAY :-

# %%
copy_of_data = data.sort_values(by=['diagnosis'])

# %%
copy_of_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 284         B        12.89         15.70           84.08      516.6
# 371         B        15.19         13.21           97.65      711.8
# 367         B        12.21         18.02           78.31      458.4
# 364         B        13.40         16.95           85.48      552.4
# 363         B        16.50         18.29          106.60      838.1
# ..        ...          ...           ...             ...        ...
# 146         M        11.80         16.58           78.99      432.0
# 379         M        11.08         18.83           73.30      361.6
# 141         M        16.11         18.05          105.10      813.0
# 138         M        14.95         17.57           96.85      678.1
# 0           M        17.99         10.38          122.80     1001.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
Benign=copy_of_data.iloc[:199,:]

# %%
Benign
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 284         B        12.89         15.70           84.08      516.6
# 371         B        15.19         13.21           97.65      711.8
# 367         B        12.21         18.02           78.31      458.4
# 364         B        13.40         16.95           85.48      552.4
# 363         B        16.50         18.29          106.60      838.1
# ..        ...          ...           ...             ...        ...
# 431         B        12.40         17.68           81.47      467.8
# 428         B        11.13         16.62           70.47      381.1
# 427         B        10.80         21.98           68.79      359.9
# 426         B        10.48         14.98           67.49      333.6
# 425         B        10.03         21.28           63.19      307.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
Malignant=copy_of_data.iloc[358:557,:]

# %%
Malignant
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 91          M        15.37         22.76          100.20      728.2
# 451         M        19.59         25.00          127.70     1191.0
# 65          M        14.78         23.94           97.40      668.3
# 77          M        18.05         16.15          120.20     1006.0
# 86          M        14.48         21.46           94.25      648.2
# ..        ...          ...           ...             ...        ...
# 352         M        25.73         17.46          174.20     2010.0
# 353         M        15.08         25.74           98.00      716.6
# 162         M        19.59         18.15          130.70     1214.0
# 161         M        19.19         15.94          126.30     1157.0
# 156         M        17.68         20.74          117.40      963.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
training_data =pd.concat([Benign,Malignant])

# %%
training_data['diagnosis'].value_counts()
# Out:
# B    199
# M    199
# Name: diagnosis, dtype: int64

# %%
training_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 284         B        12.89         15.70           84.08      516.6
# 371         B        15.19         13.21           97.65      711.8
# 367         B        12.21         18.02           78.31      458.4
# 364         B        13.40         16.95           85.48      552.4
# 363         B        16.50         18.29          106.60      838.1
# ..        ...          ...           ...             ...        ...
# 352         M        25.73         17.46          174.20     2010.0
# 353         M        15.08         25.74           98.00      716.6
# 162         M        19.59         18.15          130.70     1214.0
# 161         M        19.19         15.94          126.30     1157.0
# 156         M        17.68         20.74          117.40      963.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ### Another alternative way:-

# %%
training_data_fraction = 0.7
cv_data_fraction = 0.2
testing_data_fraction = 0.1

# %%
training_data_len = int(training_data_fraction * len(data))
cv_data_len = int(cv_data_fraction * len(data))
testing_data_len = int(testing_data_fraction * len(data))

# %%
training_data_len
# Out:
# 398

# %%
cv_data_len
# Out:
# 113

# %%
testing_data_len
# Out:
# 56

# %%
neg_training_data = data[data[data.columns[0]]== 'B'].iloc[0:int(training_data_len//2),:]

# %%
neg_training_data.shape
# Out:
# (199, 31)

# %%
pos_training_data = data[data[data.columns[0]]== 'M'].iloc[0:int(training_data_len//2),:]

# %%
pos_training_data.shape
# Out:
# (199, 31)

# %%
training_data = pd.concat((neg_training_data,pos_training_data),axis=0)

# %%
training_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19          B       13.540         14.36           87.46      566.3
# 20          B       13.080         15.71           85.63      520.0
# 21          B        9.504         12.44           60.34      273.9
# 37          B       13.030         18.42           82.61      523.8
# 46          B        8.196         16.84           51.71      201.9
# ..        ...          ...           ...             ...        ...
# 499         M       20.590         21.24          137.80     1320.0
# 501         M       13.820         24.49           92.33      595.9
# 503         M       23.090         19.83          152.10     1682.0
# 509         M       15.460         23.95          103.80      731.3
# 512         M       13.400         20.52           88.64      556.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
neg_remaining_data = data[data[data.columns[0]] == 'B'].iloc[training_data_len//2:,:]
pos_remaining_data =data[data[data.columns[0]]=='M'].iloc[training_data_len//2:,:]
remaining_data = pd.concat((neg_remaining_data,pos_remaining_data),axis=0)

# %%
randomly_shuffled_row_idx = np.random.choice(a=np.arange(start =0,stop=171),replace = False,size=171)
randomly_shuffled_row_idx
# Out:
# array([  8,  42,  47,  14, 125,  34, 159,  26, 150,  38, 113,  91, 103,
#        126,  75,  72,  99, 168,   6, 130,  41, 123,  27,  98,  33,  69,
#        140,  80,  40, 163,  62, 153,  70, 129,  66, 156,  58, 138,  50,
#        133,  51,  11, 119,  24,   9,  88,  15, 152,  21, 112, 145,  22,
#        101, 160, 148,   4, 111, 136, 110,   5,  49,  71,   1,  43,  97,
#        164, 108, 151, 144,  18,  48, 158, 141,  12, 154, 149, 139, 117,
#         53,  79,  85,  59, 120,  81,  44,  77, 102, 115,  82,  74, 155,
#         13,  45,   7,  55,  63, 142, 162,  46,  19,  32,  78,  31, 132,
#         29,  68, 116,  39,  57,  92,  37, 131, 146,  16,  93, 124,   3,
#        106, 169,  60, 157,  89, 128, 167,  23, 166,  73, 122,   0,  10,
#        143,  30,  67,  36, 114,  17, 104,  86, 161, 170,  95, 107,  56,
#        147,  65,  87, 127, 137, 135, 165, 100,  28,  61,   2,  76,  25,
#         35, 109, 134,  20, 105,  96,  84,  94,  52,  83, 118,  64, 121,
#         90,  54])

# %%
remaining_data = remaining_data.iloc[randomly_shuffled_row_idx,:]
remaining_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 375         B        16.17         16.07          106.30      788.5
# 418         B        12.70         12.17           80.88      495.0
# 423         B        13.66         19.13           89.46      575.3
# 382         B        12.05         22.72           78.75      447.8
# 527         B        12.34         12.27           78.94      468.5
# ..        ...          ...           ...             ...        ...
# 519         B        12.75         16.70           82.51      493.8
# 447         B        14.80         17.66           95.88      674.8
# 523         B        13.71         18.68           88.73      571.0
# 478         B        11.49         14.59           73.99      404.9
# 431         B        12.40         17.68           81.47      467.8
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
cv_data = remaining_data.iloc[0:cv_data_len,:]
testing_data = remaining_data.iloc[0:testing_data_len,:]

# %%
x_cv = cv_data.iloc[:,1:]
y_cv = cv_data.iloc[:,0]

# %%
y_cv
# Out:
# 375    B
# 418    B
# 423    B
# 382    B
# 527    B
#       ..
# 437    B
# 481    B
# 411    B
# 534    B
# 551    B
# Name: diagnosis, Length: 113, dtype: object

# %%
### Fitting the model now.

# %%
from sklearn.naive_bayes import GaussianNB

# %%
obj = GaussianNB()

# %%
X_train = training_data.iloc[:,1:]

# %%
Y_train = training_data.iloc[:,0]

# %%
obj.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
Y_train
# Out:
# 19     B
# 20     B
# 21     B
# 37     B
# 46     B
#       ..
# 499    M
# 501    M
# 503    M
# 509    M
# 512    M
# Name: diagnosis, Length: 398, dtype: object

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 19        13.540         14.36           87.46      566.3          0.09779
# 20        13.080         15.71           85.63      520.0          0.10750
# 21         9.504         12.44           60.34      273.9          0.10240
# 37        13.030         18.42           82.61      523.8          0.08983
# 46         8.196         16.84           51.71      201.9          0.08600
# ..           ...           ...             ...        ...              ...
# 499       20.590         21.24          137.80     1320.0          0.10850
# 501       13.820         24.49           92.33      595.9          0.11620
# 503       23.090         19.83          152.10     1682.0          0.09342
# 509       15.460         23.95          103.80      731.3          0.11830
# 512       13.400         20.52           88.64      556.7          0.11060
#
# ...

# %%
Y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
y_cv_pred =obj.predict(x_cv)

# %%
y_cv_pred
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'], dtype='<U1')

# %%
from sklearn.metrics import confusion_matrix

# %%
Confusion_Matrix = confusion_matrix(y_cv,y_cv_pred)

# %%
Confusion_Matrix
# Out:
# array([[103,   3],
#        [  2,   5]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_true=y_cv,y_pred=y_cv_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.98      0.97      0.98       106
#            M       0.62      0.71      0.67         7
#
#     accuracy                           0.96       113
#    macro avg       0.80      0.84      0.82       113
# weighted avg       0.96      0.96      0.96       113
